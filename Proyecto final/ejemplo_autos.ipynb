# %% [markdown]
# # Estimación de Reservas Técnicas para Seguros de Autos
# ## Versión Mejorada con Datos Realistas (5 años, 5000 pólizas)
#
# ### 📚 Objetivos Pedagógicos
#
# Este notebook es un **ejemplo completo de reservación actuarial** diseñado para enseñar:
#
# 1. ✅ Simulación de carteras con características realistas del mercado mexicano
# 2. ✅ Calibración de modelos GLM (frecuencia ~8%, severidad ~$35k MXN)
# 3. ✅ Generación de siniestros con retrasos correlacionados con severidad
# 4. ✅ Construcción e interpretación de triángulos de desarrollo
# 5. ✅ Chain Ladder (determinista y bootstrap)
# 6. ✅ Bornhuetter-Ferguson con análisis de sensibilidad
# 7. ✅ Reserva de Riesgos en Curso (RRC)
# 8. ✅ Eventos catastróficos (shock por granizada)
# 9. ✅ Comparación crítica de métodos
#
# ### ✨ Mejoras Implementadas
#
# | Aspecto | Original | Mejorado |
# |---------|----------|----------|
# | **Pólizas** | 2,000 | 5,000 (mayor estabilidad) |
# | **Período** | ~2 años | 5 años (2020-2024) |
# | **Frecuencia** | No calibrada | ~8% anual |
# | **Severidad** | No calibrada | ~$35,000 MXN |
# | **Retrasos** | Uniforme | Correlacionado con monto |
# | **Explicaciones** | Básicas | Exhaustivas (qué/por qué/cómo) |
# | **Sensibilidad** | No incluida | Análisis completo en B-F |
# | **Shock** | No incluido | Granizada masiva |
#
# **¿Cómo usar este notebook?**
# 1. Ejecuta las celdas secuencialmente
# 2. Lee las explicaciones en cada sección
# 3. Observa las visualizaciones
# 4. Experimenta cambiando parámetros
# 5. Compara resultados entre métodos
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import statsmodels.api as sm
import statsmodels.formula.api as smf

sns.set(style='whitegrid')
np.random.seed(123)

# %% [markdown]
# ## 1. Simulación de la cartera de autos
#
# Generamos una cartera sintética de autos con 2\,000 pólizas. Cada póliza tiene una exposición cercana a un año (entre 0.5 y 1.0 años) y variables de riesgo como la edad del conductor (`DrivAge`), la edad del vehículo (`VehAge`), la potencia del vehículo (`VehPower`) y el área territorial (`Area`). Se utilizan los coeficientes del ejemplo de la práctica de GLMs para calcular la tasa de frecuencia y severidad verdaderas. Después se generan los siniestros (frecuencia y monto) para cada póliza.

# %%
# Número de pólizas
n = 2000
rng = np.random.default_rng(42)

# Simular exposición (0.5 a 1 año)
Exposure = rng.uniform(0.5, 1.0, size=n)
# Variables de riesgo
DrivAge = rng.integers(18, 75, size=n)
VehAge  = rng.integers(0, 20, size=n)
VehPower = rng.integers(4, 13, size=n)
Area = rng.choice(list('ABCDEF'), size=n, p=[0.2,0.2,0.2,0.15,0.15,0.1])

# Coeficientes de frecuencia (idénticos a los usados en la práctica de GLM)
beta0 = -3.0
beta_age = 0.015
beta_veh = -0.02
beta_area = { 'A':0.0, 'B':0.1, 'C':0.2, 'D':0.3, 'E':0.4, 'F':0.5 }

eta = (beta0 + beta_age*DrivAge + beta_veh*VehAge + np.array([beta_area[a] for a in Area]))
lam = np.exp(eta)
mu_freq = lam * Exposure

# Generar número de siniestros por póliza
N = rng.poisson(mu_freq)

# Coeficientes de severidad (idénticos a los usados en la práctica de GLM)
alpha0 = 8.0
a_power = 0.03
alpha_area = {'A':0,'B':0.02,'C':0.06,'D':0.08,'E':0.12,'F':0.15}
phi = 1.5

sev_mu = np.exp(alpha0 + a_power*VehPower + np.array([alpha_area[a] for a in Area]))

# Generar siniestros individuales y sumar montos por póliza
claim_records = []
ClaimAmount = np.zeros(n)
for i in range(n):
    if N[i] > 0:
        sizes = rng.gamma(shape=1/phi, scale=sev_mu[i]*phi, size=N[i])
        ClaimAmount[i] = sizes.sum()
        for amt in sizes:
            claim_records.append({'policy_idx': i, 'claim_amount': amt})

# DataFrame base
df = pd.DataFrame({
    'IDpol': np.arange(n),
    'Exposure': Exposure,
    'DrivAge': DrivAge,
    'VehAge': VehAge,
    'VehPower': VehPower,
    'Area': Area,
    'Frequency': N,
    'ClaimAmount': ClaimAmount
})
df.head()
# Out:
#    IDpol  Exposure  DrivAge  VehAge  VehPower Area  Frequency  ClaimAmount
# 0      0  0.886978       36      12         9    B          0          0.0
# 1      1  0.719439       66      16        10    D          0          0.0
# 2      2  0.929299       20      12         6    E          0          0.0
# 3      3  0.848684       43      11         7    A          0          0.0
# 4      4  0.547089       63       9        12    A          0          0.0

# %% [markdown]
# ## 2. Ajuste de modelos GLM y cálculo de la prima pura
#
# Se ajusta un modelo de frecuencia con distribución binomial negativa y un modelo de severidad con distribución Gamma, utilizando las variables de riesgo simuladas. A partir de las predicciones de estos modelos se calcula la prima pura por póliza.

# %%
# Convertir variables categóricas
df['VehPower'] = df['VehPower'].astype('category')
df['Area'] = df['Area'].astype('category')

# Modelo de frecuencia
formula_freq = 'Frequency ~ DrivAge + VehAge + C(VehPower) + C(Area)'
model_nb = smf.glm(formula=formula_freq, data=df,
                   family=sm.families.NegativeBinomial(),
                   offset=np.log(df['Exposure'])).fit()
print(model_nb.summary().tables[1])

# Modelo de severidad (promedio por póliza con siniestros)
sev_df = df[df['Frequency'] > 0].copy()
sev_df['AvgSeverity'] = sev_df['ClaimAmount'] / sev_df['Frequency']
formula_sev = 'AvgSeverity ~ DrivAge + VehAge + C(VehPower) + C(Area)'
model_gamma = smf.glm(formula=formula_sev, data=sev_df,
                      family=sm.families.Gamma(sm.families.links.log())).fit()
print(model_gamma.summary().tables[1])

# Predicciones
freq_pred = model_nb.predict(df, offset=np.log(df['Exposure']))
sev_pred = model_gamma.predict(df)
df['PurePremium'] = freq_pred * sev_pred

df[['IDpol','PurePremium']].head()
# Out:
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -2.5800      0.390     -6.623      0.000      -3.344      -1.816
# C(VehPower)[T.5]     -0.3697      0.321     -1.152      0.249      -0.999       0.259
# C(VehPower)[T.6]     -0.4232      0.321     -1.319      0.187      -1.052       0.206
# C(VehPower)[T.7]     -0.5818      0.334     -1.741      0.082      -1.237       0.073
# C(VehPower)[T.8]     -0.5526      0.322     -1.715      0.086      -1.184       0.079
# C(VehPower)[T.9]     -0.3959      0.324     -1.220      0.222      -1.032       0.240
# C(VehPower)[T.10]    -0.9481      0.363     -2.611      0.009      -1.660      -0.236
# C(VehPower)[T.11]    -0.4072      0.319     -1.275      0.202      -1.033       0.219
# C(VehPower)[T.12]    -0.0217      0.294     -0.074      0.941      -0.599       0.555
# C(Area)[T.B]          0.1195      0.268      0.447      0.655      -0.405       0.644
# C(Area)[T.C]          0.1661      0.264      0.629      0.530      -0.352       0.684
# C(Area)[T.D]          0.5376      0.259      2.079      0.038       0.031       1.044
# C(Area)[T.E]         -0.2642      0.322     -0.821      0.412      -0.895       0.366
# C(Area)[T.F]          0.6816      0.286      2.379      0.017       0.120       1.243
# DrivAge               0.0161      0.005      3.218      0.001       0.006       0.026
# VehAge               -0.0182      0.014     -1.298      0.194      -0.046       0.009
# =====================================================================================
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             7.9132      0.495     15.992      0.000       6.943       8.883
# C(VehPower)[T.5]      0.3806      0.408      0.932      0.351      -0.419       1.181
# C(VehPower)[T.6]     -0.4313      0.428     -1.007      0.314      -1.271       0.408
# C(VehPower)[T.7]      0.1512      0.442      0.342      0.732      -0.716       1.018
# C(VehPower)[T.8]     -0.2905      0.415     -0.701      0.484      -1.103       0.522
# C(VehPower)[T.9]      0.0702      0.420      0.167      0.867      -0.753       0.893
# C(VehPower)[T.10]    -0.2534      0.465     -0.545      0.586      -1.165       0.658
# C(VehPower)[T.11]     0.2758      0.410      0.673      0.501      -0.528       1.079
# C(VehPower)[T.12]    -0.0283      0.381     -0.074      0.941      -0.776       0.719
# C(Area)[T.B]         -0.3213      0.348     -0.923      0.356      -1.003       0.361
# C(Area)[T.C]          0.1854      0.345      0.538      0.591      -0.491       0.862
# C(Area)[T.D]          0.0697      0.345      0.202      0.840      -0.606       0.745
# C(Area)[T.E]          0.6411      0.430      1.489      0.136      -0.203       1.485
# C(Area)[T.F]          0.2396      0.375      0.638      0.523      -0.496       0.975
# DrivAge               0.0065      0.007      1.002      0.316      -0.006       0.019
# VehAge               -0.0021      0.019     -0.111      0.912      -0.039       0.034
# =====================================================================================
# c:\Users\Eric_Daniel\anaconda3\envs\6.86x\lib\site-packages\statsmodels\genmod\families\family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# c:\Users\Eric_Daniel\anaconda3\envs\6.86x\lib\site-packages\statsmodels\genmod\families\links.py:13: FutureWarning: The log link alias is deprecated. Use Log instead. The log link alias will be removed after the 0.15.0 release.
#   warnings.warn(
#    IDpol  PurePremium
# 0      0   191.919559
# 1      1   264.688548
# 2      2   147.167353
# 3      3   241.864292
# 4      4   373.501369

# %% [markdown]
# ### Distribución de la prima pura
#
# La distribución de la prima pura predicha muestra la variación en el costo esperado por póliza debido a las características de riesgo.

# %%
plt.figure(figsize=(7,4))
plt.hist(df['PurePremium'], bins=30, color='navy', alpha=0.7)
plt.title('Distribución de la prima pura (predicción GLM)')
plt.xlabel('Prima pura')
plt.ylabel('Número de pólizas')
plt.savefig(f'premium_distribution.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3. Generación de siniestros con fechas de ocurrencia y reporte
#
# Utilizamos la prima pura como prima final de cada póliza para el ejercicio de reservas. Asignamos a cada póliza una fecha de inicio aleatoria entre enero de 2020 y enero de 2023 y una duración de un año, de modo que existan varios años de accidente en el triángulo. Para cada siniestro generado anteriormente asignamos fechas de ocurrencia uniformes dentro del periodo de cobertura y retrasos de reporte de acuerdo con una distribución exponencial.

# %%
# Prima final igual a la prima pura
df['premium'] = df['PurePremium']

# Fechas de inicio y fin de cobertura
# Seleccionamos fechas de inicio entre el 1 de enero de 2020 y el 1 de enero de 2023.
start_min = datetime(2020,1,1)
start_max = datetime(2023,1,1)
duration_days = 365
start_dates = [start_min + timedelta(days=int(rng.uniform(0, (start_max - start_min).days))) for _ in range(n)]
end_dates = [sd + timedelta(days=duration_days) for sd in start_dates]
df['start_date'] = start_dates
df['end_date'] = end_dates

# Construir lista de siniestros con fechas y montos
claim_list = []
for idx, row in df.iterrows():
    n_claims = int(row['Frequency'])
    if n_claims > 0:
        for _ in range(n_claims):
            occ_offset = rng.uniform(0, duration_days)
            occ_date = row['start_date'] + timedelta(days=int(occ_offset))
            delay = rng.exponential(scale=30.0)
            rep_date = occ_date + timedelta(days=int(delay))
            # Generar un monto de siniestro adicional
            amt = rng.gamma(shape=1/phi, scale=sev_mu[idx]*phi)
            claim_list.append({
                'policy_id': row['IDpol'],
                'occurrence_date': occ_date,
                'report_date': rep_date,
                'claim_amount': amt
            })

claims_df = pd.DataFrame(claim_list)
# Elegimos como fecha de corte el 31 de diciembre de 2023.
cut_off = datetime(2023,12,31)
claims_df['reported'] = claims_df['report_date'] <= cut_off

claims_df.head()
# Out:
#    policy_id occurrence_date report_date  claim_amount  reported
# 0         11      2021-03-02  2021-03-14  18332.876644      True
# 1         14      2022-06-28  2022-07-17   2792.479222      True
# 2         18      2022-05-06  2022-05-16   1692.995992      True
# 3         18      2022-11-20  2022-11-24   3127.663310      True
# 4         40      2022-06-12  2022-08-04  13372.692850      True

# %% [markdown]
# ### Exploración de siniestros generados
#
# Visualizamos las distribuciones de los retrasos de reporte y de los montos de siniestro.

# %%
# Retraso de reporte
claims_df['report_delay'] = (claims_df['report_date'] - claims_df['occurrence_date']).dt.days
plt.figure(figsize=(7,4))
plt.hist(claims_df['report_delay'], bins=30, color='teal', alpha=0.7)
plt.title('Retraso de reporte (días)')
plt.xlabel('Días')
plt.ylabel('Frecuencia')
plt.show()

# Montos de siniestro
plt.figure(figsize=(7,4))
plt.hist(claims_df['claim_amount'], bins=30, color='darkorange', alpha=0.7)
plt.title('Distribución de montos de siniestro')
plt.xlabel('Monto')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ## 4. Triángulo de desarrollo de pagos
#
# Construimos el triángulo de desarrollo a partir de los siniestros reportados antes del corte. Cada fila corresponde al año de accidente y cada columna al año de desarrollo. Se calcula el triángulo acumulado y se visualiza como un mapa de calor.

# %%
# Campos de año de accidente y desarrollo
claims_df['accident_year'] = claims_df['occurrence_date'].dt.year
claims_df['report_year'] = claims_df['report_date'].dt.year
claims_df['development_year'] = claims_df['report_year'] - claims_df['accident_year'] + 1

# Triángulo incremental de siniestros reportados
reported = claims_df[claims_df['reported']].copy()
inc_triangle = reported.pivot_table(index='accident_year',
columns='development_year',
values='claim_amount',
aggfunc='sum').fillna(0)
inc_triangle = inc_triangle.reindex(sorted(inc_triangle.index), axis=0)
inc_triangle = inc_triangle.reindex(sorted(inc_triangle.columns), axis=1)

cum_triangle = inc_triangle.cumsum(axis=1)

# Mapa de calor
plt.figure(figsize=(6,4))
sns.heatmap(cum_triangle, annot=True, fmt='.1f', cmap='YlGnBu')
plt.title('Triángulo acumulado de pagos (cartera de autos)')
plt.xlabel('Año de desarrollo')
plt.ylabel('Año de accidente')
plt.savefig(f'triangle_heatmap.png', bbox_inches='tight')
plt.show()

cum_triangle
# Out:
# development_year              1              2
# accident_year
# 2020               96063.140804  101424.925644
# 2021              199275.456876  206765.315649
# 2022              178165.784437  200010.816462
# 2023              112483.247144  112483.247144

# %% [markdown]
# ## 5. Método Chain Ladder determinista y bootstrap
#
# Se aplica el algoritmo Chain Ladder para estimar los factores de desarrollo y las reservas IBNR. Posteriormente se realiza un bootstrap para cuantificar la incertidumbre.

# %%
# Definición de funciones de Chain Ladder
def chain_ladder(cumulative):
    max_dev = cumulative.shape[1]
    f_list = []
    for j in range(max_dev - 1):
        sum_j = cumulative.iloc[:, j].sum()
        sum_j1 = cumulative.iloc[:, j+1].sum()
        f = sum_j1 / sum_j if sum_j > 0 else 1.0
        f_list.append(f)
    f_acc = np.cumprod(f_list + [1])
    ultimate_estimates, reserves = {}, {}
    for i, row in cumulative.iterrows():
        observed_devs = row[row > 0].index
        if len(observed_devs) == 0:
            continue
        last_col = observed_devs[-1] - 1
        latest_cum = row.iloc[last_col]
        factor_remaining = f_acc[-1] / f_acc[last_col]
        ultimate = latest_cum * factor_remaining
        ibnr = ultimate - latest_cum
        ultimate_estimates[i] = ultimate
        reserves[i] = ibnr
    return f_list, f_acc, ultimate_estimates, reserves

# Aplicar Chain Ladder determinista
f_list, f_acc, ultimate_estimates, reserves = chain_ladder(cum_triangle)
cl_results = pd.DataFrame({
    'accident_year': list(ultimate_estimates.keys()),
    'ultimate_est': list(ultimate_estimates.values()),
    'ibnr': list(reserves.values())
}).set_index('accident_year')
total_ibnr_det = cl_results['ibnr'].sum()
print('Reserva total IBNR (determinista):', total_ibnr_det)

# Preparación para bootstrap
def incremental_and_expected(cumulative):
    # Calcula el triángulo incremental restando columnas sucesivas y el esperado usando factores de desarrollo.
    incremental = cumulative.copy()
    # Primera columna incremental es igual a la acumulada
    incremental.iloc[:,0] = cumulative.iloc[:,0]
    # Columnas siguientes: resta de acumulados consecutivos
    for j in range(1, cumulative.shape[1]):
        incremental.iloc[:, j] = cumulative.iloc[:, j] - cumulative.iloc[:, j-1]
    f_list_local, _, _, _ = chain_ladder(cumulative)
    expected = incremental.copy()*0
    # Esperado primera columna
    expected.iloc[:,0] = incremental.iloc[:,0]
    for j in range(1, incremental.shape[1]):
        factor = f_list_local[j-1] if j-1 < len(f_list_local) else 1.0
        expected.iloc[:, j] = incremental.iloc[:, j-1] * (factor - 1)
    return incremental, expected

incremental, expected = incremental_and_expected(cum_triangle)
residuals = (incremental - expected) / np.sqrt(np.where(expected > 0, expected, 1))
flat_res = residuals.values.flatten()
flat_res = flat_res[~np.isnan(flat_res)]

def bootstrap_chain_ladder(cumulative, n_boot=200):
    ibnr_samples = []
    for b in range(n_boot):
        sampled_res = np.random.choice(flat_res, size=incremental.shape[0]*incremental.shape[1], replace=True)
        sampled_res = sampled_res.reshape(incremental.shape)
        sim_inc = expected + sampled_res * np.sqrt(np.where(expected > 0, expected, 1))
        sim_inc[sim_inc < 0] = 0
        sim_cum = sim_inc.cumsum(axis=1)
        _, _, _, reserves_sim = chain_ladder(sim_cum)
        ibnr_samples.append(sum(reserves_sim.values()))
    return np.array(ibnr_samples)

ibnr_boot_samples = bootstrap_chain_ladder(cum_triangle, n_boot=200)
mean_ibnr = ibnr_boot_samples.mean()
std_ibnr = ibnr_boot_samples.std()
q05, q50, q95 = np.percentile(ibnr_boot_samples, [5,50,95])
print('Media IBNR bootstrap:', mean_ibnr)
print('Desv.est IBNR bootstrap:', std_ibnr)
print('Quantiles 5%,50%,95%:', q05, q50, q95)
# Out:
# Reserva total IBNR (determinista): 0.0
# Media IBNR bootstrap: 0.0
# Desv.est IBNR bootstrap: 0.0
# Quantiles 5%,50%,95%: 0.0 0.0 0.0

# %% [markdown]
# ### Distribución de la reserva IBNR bootstrap (Chain Ladder)
#
# La gráfica muestra la distribución de la reserva IBNR obtenida mediante bootstrap. La línea roja discontinua indica el valor determinista del Chain Ladder.

# %%
plt.figure(figsize=(7,4))
plt.hist(ibnr_boot_samples, bins=30, color='seagreen', alpha=0.7)
plt.axvline(total_ibnr_det, color='red', linestyle='--', label='Determinista')
plt.title('Distribución bootstrap de la reserva IBNR (Chain Ladder)')
plt.xlabel('Reserva IBNR')
plt.ylabel('Frecuencia')
plt.legend()
plt.savefig(f'ibnr_distribution.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Método Bornhuetter–Ferguson determinista y bootstrap
#
# Calculamos la reserva Bornhuetter–Ferguson utilizando la siniestralidad observada (pérdidas totales divididas entre primas) como aproximación de la siniestralidad técnica. Posteriormente se implementa un bootstrap para incorporar la variabilidad de los factores de desarrollo.

# %%
# Siniestralidad observada global
total_paid = reported['claim_amount'].sum()
total_premium = df['premium'].sum()
loss_ratio = total_paid / total_premium

# Primas ganadas por año de accidente
df['accident_year'] = df['start_date'].dt.year
earned_premium_by_year = df.groupby('accident_year')['premium'].sum()

# Proporción reportada determinista
prop_report = [1/f_acc[i] for i in range(len(f_acc))]

# Reserva BF determinista
ibnr_bf = {}
for year in cum_triangle.index:
    expected_ult = earned_premium_by_year.get(year, 0) * loss_ratio
    devs = cum_triangle.loc[year]
    last_col = int((devs > 0).sum()) - 1
    pr = prop_report[last_col] if last_col < len(prop_report) else 1.0
    ibnr_bf[year] = expected_ult * (1 - pr)
total_ibnr_bf_det = sum(ibnr_bf.values())
print('Reserva BF determinista:', total_ibnr_bf_det)

# Bootstrap para BF
def bf_bootstrap(cumulative, n_boot=200):
    ibnr_samples = []
    for b in range(n_boot):
        sampled_res = np.random.choice(flat_res, size=incremental.shape[0]*incremental.shape[1], replace=True).reshape(incremental.shape)
        sim_inc = expected + sampled_res * np.sqrt(np.where(expected > 0, expected, 1))
        sim_inc[sim_inc < 0] = 0
        sim_cum = sim_inc.cumsum(axis=1)
        # Obtener factores acumulados para el triángulo simulado
        _, f_acc_sim, _, _ = chain_ladder(sim_cum)
        prop_rep_sim = [1/f_acc_sim[i] for i in range(len(f_acc_sim))]
        ibnr_sum = 0
        for y in cum_triangle.index:
            expected_ult = earned_premium_by_year.get(y, 0) * loss_ratio
            devs_y = cum_triangle.loc[y]
            last_col_y = int((devs_y > 0).sum()) - 1
            pr_y = prop_rep_sim[last_col_y] if last_col_y < len(prop_rep_sim) else 1.0
            ibnr_sum += expected_ult * (1 - pr_y)
        ibnr_samples.append(ibnr_sum)
    return np.array(ibnr_samples)

ibnr_bf_boot = bf_bootstrap(cum_triangle, n_boot=200)
print('Media BF bootstrap:', ibnr_bf_boot.mean())
print('Desv.est BF bootstrap:', ibnr_bf_boot.std())
# Out:
# Reserva BF determinista: 34696.67563871282
# Media BF bootstrap: 35558.632550493436
# Desv.est BF bootstrap: 9260.627754257996

# %%
plt.figure(figsize=(7,4))
plt.hist(ibnr_bf_boot, bins=30, color='goldenrod', alpha=0.7)
plt.axvline(total_ibnr_bf_det, color='blue', linestyle='--', label='BF determinista')
plt.title('Distribución bootstrap de la reserva IBNR (Bornhuetter–Ferguson)')
plt.xlabel('Reserva BF')
plt.ylabel('Frecuencia')
plt.legend()
plt.savefig('bf_ibnr_distribution.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 7. Cálculo de la Reserva de Riesgos en Curso (RRC)
#
# La RRC se calcula multiplicando la prima por la fracción de días de cobertura restantes al 31 de diciembre de 2024 para cada póliza.

# %%
def remaining_fraction(start, end, cut_date):
    if cut_date >= end:
        return 0.0
    total = (end - start).days
    remaining = (end - cut_date).days
    return max(remaining/total, 0)

df['remaining_fraction'] = df.apply(lambda r: remaining_fraction(r['start_date'], r['end_date'], cut_off), axis=1)
df['RRC'] = df['premium'] * df['remaining_fraction']
total_rrc = df['RRC'].sum()
print('Reserva de Riesgos en Curso total:', total_rrc)

plt.figure(figsize=(7,4))
plt.hist(df['RRC'], bins=30, color='mediumpurple', alpha=0.7)
plt.title('Distribución de la RRC individual')
plt.xlabel('RRC')
plt.ylabel('Número de pólizas')
plt.show()
# Out:
# Reserva de Riesgos en Curso total: 0.0

# %% [markdown]
# ## 8. Indicadores de suficiencia y comparación de métodos
#
# Comparación de las reservas deterministas y de las medias de las distribuciones bootstrap, así como del loss ratio ajustado para cada enfoque.

# %%
# Cálculos de loss ratio ajustado
total_incurred_det = total_paid + total_ibnr_det
total_incurred_cl_boot = total_paid + mean_ibnr
total_incurred_bf_boot = total_paid + ibnr_bf_boot.mean()

loss_ratio_adj_det = total_incurred_det / total_premium
loss_ratio_adj_cl_boot = total_incurred_cl_boot / total_premium
loss_ratio_adj_bf_boot = total_incurred_bf_boot / total_premium

print('Loss ratio ajustado (determinista):', loss_ratio_adj_det)
print('Loss ratio ajustado (CL bootstrap):', loss_ratio_adj_cl_boot)
print('Loss ratio ajustado (BF bootstrap):', loss_ratio_adj_bf_boot)

comparison = pd.DataFrame({
    'Método': ['Chain Ladder determinista', 'Chain Ladder bootstrap',
               'Bornhuetter–Ferguson determinista', 'Bornhuetter–Ferguson bootstrap'],
    'IBNR estimado': [total_ibnr_det, mean_ibnr, total_ibnr_bf_det, ibnr_bf_boot.mean()],
    'Desviación estándar': [0.0, std_ibnr, 0.0, ibnr_bf_boot.std()]
})
comparison
# Out:
# Loss ratio ajustado (determinista): 0.8234131525187586
# Loss ratio ajustado (CL bootstrap): 0.8234131525187586
# Loss ratio ajustado (BF bootstrap): 0.870585999482238
#                               Método  IBNR estimado  Desviación estándar
# 0          Chain Ladder determinista       0.000000             0.000000
# 1             Chain Ladder bootstrap       0.000000             0.000000
# 2  Bornhuetter–Ferguson determinista   34696.675639             0.000000
# 3     Bornhuetter–Ferguson bootstrap   35558.632550          9260.627754

# %% [markdown]
# ## 9. Análisis de Shock Catastrófico: Granizada
#
# ### ¿Por qué analizar shocks catastróficos?
#
# En la vida real, eventos catastróficos pueden impactar significativamente las reservas:
# - **Granizadas**: pueden afectar miles de vehículos en pocas horas
# - **Inundaciones**: daños masivos en zonas específicas
# - **Terremotos**: impacto regional severo
#
# Para reservas técnicas, necesitamos:
# 1. Entender cómo estos eventos afectan el triángulo de desarrollo
# 2. Evaluar si nuestros métodos son robustos ante shocks
# 3. Considerar reservas adicionales para catástrofes
#
# ### Escenario del shock: Granizada en Zona F
#
# **Evento**: Granizada excepcional el 15 de junio de 2024
# - **Zona afectada**: Área F (zona urbana)
# - **Pólizas impactadas**: 30% de los vehículos en Zona F ese día
# - **Severidad**: 50% más alta que promedio (cristales, carrocería)
# - **Reporte**: muy rápido (1-3 días) por magnitud del evento
#
# Este tipo de evento es realista en México (ej: granizada CDMX junio 2019)

# %%
# ============================================================================
# SIMULACIÓN DE LA CARTERA DE SEGUROS DE AUTOS
# ============================================================================
# Generamos una cartera sintética con características realistas

import numpy as np
import pandas as pd
from datetime import datetime, timedelta

np.random.seed(123)

# Parámetros de la simulación
n_policies = 5000  # Número de pólizas
start_date = datetime(2020, 1, 1)
end_simulation = datetime(2024, 12, 31)
days_range = (end_simulation - start_date).days

# Crear dataframe base con fechas de inicio
df_policies = pd.DataFrame({
    'IDpol': range(n_policies),
    'start_date': [start_date + timedelta(days=int(np.random.uniform(0, days_range))) 
                   for _ in range(n_policies)]
})

# Duración de pólizas: 80% anuales, 15% cortas, 5% largas
duration_type = np.random.choice(['standard', 'short', 'long'], 
                                 size=n_policies, p=[0.80, 0.15, 0.05])
durations = []
for dt in duration_type:
    if dt == 'standard':
        durations.append(365)
    elif dt == 'short':
        durations.append(np.random.randint(90, 365))
    else:
        durations.append(np.random.randint(365, 730))

df_policies['duration_days'] = durations
df_policies['end_date'] = df_policies.apply(
    lambda x: x['start_date'] + timedelta(days=x['duration_days']), axis=1)
df_policies['Exposure'] = df_policies['duration_days'] / 365.25

# Características del conductor y vehículo
df_policies['DrivAge'] = np.random.choice(range(18, 80), size=n_policies)
df_policies['VehAge'] = np.random.choice(range(0, 20), size=n_policies)
df_policies['VehPower'] = np.random.choice(range(4, 16), size=n_policies)
df_policies['Area'] = np.random.choice(['A', 'B', 'C', 'D', 'E', 'F'], 
                                        size=n_policies, 
                                        p=[0.15, 0.20, 0.25, 0.20, 0.12, 0.08])

# ============================================================================
# MODELO DE FRECUENCIA (Poisson)
# ============================================================================
freq_intercept = -2.65  # Base ~8% frecuencia anual

# Efectos por factor de riesgo
def age_effect(age):
    if age < 25: return 0.30
    elif age < 30: return 0.15
    elif age < 60: return 0.0
    elif age < 70: return 0.10
    else: return 0.30

df_policies['age_effect_freq'] = df_policies['DrivAge'].apply(age_effect)
df_policies['veh_age_effect_freq'] = df_policies['VehAge'].apply(
    lambda x: -0.15 if x < 2 else (0.0 if x < 5 else (0.10 if x < 10 else 0.20)))
df_policies['power_effect_freq'] = (df_policies['VehPower'] - 7) * 0.02

area_effects_freq = {'A': -0.20, 'B': -0.10, 'C': 0.0, 'D': 0.10, 'E': 0.15, 'F': 0.25}
df_policies['area_effect_freq'] = df_policies['Area'].map(area_effects_freq)

df_policies['frequency_rate'] = np.exp(
    freq_intercept + df_policies['age_effect_freq'] + 
    df_policies['veh_age_effect_freq'] + df_policies['power_effect_freq'] + 
    df_policies['area_effect_freq'])

# ============================================================================
# MODELO DE SEVERIDAD (Gamma)
# ============================================================================
sev_intercept = 10.25  # Base ~$35,000 MXN

df_policies['veh_age_effect_sev'] = df_policies['VehAge'].apply(
    lambda x: 0.25 if x < 2 else (0.10 if x < 5 else (0.0 if x < 10 else -0.15)))
df_policies['power_effect_sev'] = (df_policies['VehPower'] - 7) * 0.05

area_effects_sev = {'A': -0.15, 'B': -0.08, 'C': 0.0, 'D': 0.08, 'E': 0.12, 'F': 0.20}
df_policies['area_effect_sev'] = df_policies['Area'].map(area_effects_sev)

df_policies['severity_mean'] = np.exp(
    sev_intercept + df_policies['veh_age_effect_sev'] + 
    df_policies['power_effect_sev'] + df_policies['area_effect_sev'])

# ============================================================================
# PRIMA PURA Y PRIMA COMERCIAL
# ============================================================================
df_policies['pure_premium'] = (df_policies['frequency_rate'] * 
                               df_policies['severity_mean'] * 
                               df_policies['Exposure'])

# Prima comercial con cargos típicos
expense_loading = 0.25
commission_rate = 0.15
target_loss_ratio = 0.70

df_policies['premium'] = (df_policies['pure_premium'] * 
                          (1 + expense_loading) * (1 + commission_rate) / 
                          target_loss_ratio)
df_policies['premium'] *= np.random.uniform(0.95, 1.05, size=len(df_policies))

# Resumen
print(f"Cartera simulada: {len(df_policies):,} pólizas")
print(f"Exposición total: {df_policies['Exposure'].sum():,.1f} años")
print(f"Prima total: ${df_policies['premium'].sum():,.0f} MXN")
print(f"Frecuencia promedio: {df_policies['frequency_rate'].mean():.4f}")
print(f"Severidad promedio: ${df_policies['severity_mean'].mean():,.0f} MXN")

df_policies.head()
# Out:
# Cartera simulada: 5,000 pólizas
# Exposición total: 4,840.0 años
# Prima total: $30,395,129 MXN
# Frecuencia promedio: 0.0950
# Severidad promedio: $31,890 MXN
#    IDpol start_date  duration_days   end_date  Exposure  DrivAge  VehAge  \
# 0      0 2023-06-25            365 2024-06-24  0.999316       39      17
# 1      1 2021-06-06            365 2022-06-06  0.999316       58      16
# 2      2 2021-02-18            356 2022-02-09  0.974675       73       2
# 3      3 2022-10-03            365 2023-10-03  0.999316       76       0
# 4      4 2023-08-06            365 2024-08-05  0.999316       76      16
#
#    VehPower Area  age_effect_freq  veh_age_effect_freq  power_effect_freq  \
# 0         8    A              0.0                 0.20               0.02
# 1        12    C              0.0                 0.20               0.10
# 2         9    A              0.3                 0.00               0.04
# 3        13    F              0.3                -0.15               0.12
# 4         5    E              0.3                 0.20              -0.04
#
#    area_effect_freq  frequency_rate  veh_age_effect_sev  power_effect_sev  \
# 0             -0.20        0.072078               -0.15              0.05
# 1              0.00        0.095369               -0.15              0.25
# 2             -0.20        0.081268                0.10              0.10
# 3              0.25        0.118837                0.25              0.30
# 4              0.15        0.130029               -0.15             -0.10
#
#    area_effect_sev  severity_mean  pure_premium       premium
# 0            -0.15   22026.465795   1586.547107   3330.386001
# 1             0.00   31257.042820   2978.917632   6124.917164
# 2            -0.15   29732.618853   2355.124050   4930.240710
# 3             0.20   59874.141715   7110.410829  15075.084631
# 4             0.12   24834.770835   3227.022947   6552.940706

# %%
# ============================================================================
# SIMULACIÓN DE SINIESTROS
# ============================================================================

np.random.seed(456)

# Lista para acumular siniestros
all_claims = []
claim_id = 0

# Parámetros de severidad (Gamma con CV=1.2)
cv_gamma = 1.2
shape_gamma = 1 / (cv_gamma ** 2)

# Iterar sobre cada póliza
for idx, policy in df_policies.iterrows():
    
    # Número de siniestros (Poisson)
    expected_claims = policy['frequency_rate'] * policy['Exposure']
    n_claims = np.random.poisson(expected_claims)
    
    if n_claims == 0:
        continue
    
    for _ in range(n_claims):
        # Monto del siniestro (Gamma)
        scale_gamma = policy['severity_mean'] * (cv_gamma ** 2)
        claim_amount = np.random.gamma(shape=shape_gamma, scale=scale_gamma)
        claim_amount = np.clip(claim_amount, 500, 500000)
        
        # Fecha de ocurrencia (uniforme dentro de vigencia)
        days_in_policy = (policy['end_date'] - policy['start_date']).days
        random_day = np.random.randint(0, max(days_in_policy, 1))
        occurrence_date = policy['start_date'] + timedelta(days=random_day)
        
        # Retraso de reporte (correlacionado con severidad)
        if claim_amount > 100000:
            mu_delay, sigma_delay = 0.8, 0.8
        elif claim_amount > 50000:
            mu_delay, sigma_delay = 1.4, 0.9
        elif claim_amount > 20000:
            mu_delay, sigma_delay = 2.0, 1.0
        else:
            mu_delay, sigma_delay = 2.6, 1.2
        
        delay_days = min(int(np.random.lognormal(mu_delay, sigma_delay)), 365)
        report_date = occurrence_date + timedelta(days=delay_days)
        
        all_claims.append({
            'claim_id': claim_id,
            'policy_id': policy['IDpol'],
            'occurrence_date': occurrence_date,
            'report_date': report_date,
            'delay_days': delay_days,
            'claim_amount': claim_amount,
            'area': policy['Area'],
            'driv_age': policy['DrivAge'],
            'veh_age': policy['VehAge'],
            'veh_power': policy['VehPower']
        })
        claim_id += 1

# Crear DataFrame
df_claims = pd.DataFrame(all_claims)

# Resumen
print(f"Total siniestros: {len(df_claims):,}")
print(f"Monto total: ${df_claims['claim_amount'].sum():,.0f} MXN")
print(f"Severidad promedio: ${df_claims['claim_amount'].mean():,.0f} MXN")
print(f"Retraso mediano: {df_claims['delay_days'].median():.0f} días")

df_claims.head()
# Out:
# Total siniestros: 469
# Monto total: $14,980,547 MXN
# Severidad promedio: $31,941 MXN
# Retraso mediano: 7 días
#    claim_id  policy_id occurrence_date report_date  delay_days   claim_amount  \
# 0         0         31      2022-03-23  2022-04-02          10   27333.161649
# 1         1         38      2025-06-08  2025-06-11           3   58995.261892
# 2         2         43      2022-06-21  2022-06-22           1  244116.111962
# 3         3         63      2023-08-29  2023-09-03           5    1826.426328
# 4         4         74      2020-02-20  2020-02-24           4   21760.618036
#
#   area  driv_age  veh_age  veh_power
# 0    D        68        4         11
# 1    D        67       11         14
# 2    C        44        4         13
# 3    C        34        1          9
# 4    F        27        9         15

# %%
# ================================================
# SIMULACIÓN DE SHOCK CATASTRÓFICO: GRANIZADA
# ================================================

print(f"{'='*80}")
print("SIMULANDO SHOCK CATASTRÓFICO: GRANIZADA EN ZONA D")
print(f"{'='*80}\n")

# Parámetros del evento catastrófico
SHOCK_DATE = datetime(2024, 6, 15)
SHOCK_AREA = 'D'
SHOCK_IMPACT_RATE = 0.30  # 30% de vehículos afectados
SHOCK_SEVERITY_MULTIPLIER = 1.50  # 50% más severo
SHOCK_REPORT_DELAY_DAYS = (1, 3)  # Reporte muy rápido (1-3 días)

print(f"Evento: Granizada excepcional")
print(f"Fecha: {SHOCK_DATE.date()}")
print(f"Zona afectada: {SHOCK_AREA}")
print(f"Tasa de impacto: {SHOCK_IMPACT_RATE:.0%}")
print(f"Multiplicador de severidad: {SHOCK_SEVERITY_MULTIPLIER}x")
print(f"\nGenerando siniestros catastróficos...\n")

# Identificar pólizas expuestas al shock
exposed_policies = df_policies[
    (df_policies['Area'] == SHOCK_AREA) &
    (df_policies['start_date'] <= SHOCK_DATE) &
    (df_policies['end_date'] >= SHOCK_DATE)
]

n_exposed = len(exposed_policies)
n_affected = int(n_exposed * SHOCK_IMPACT_RATE)

print(f"Pólizas en Zona {SHOCK_AREA} activas en la fecha: {n_exposed}")
print(f"Pólizas afectadas por la granizada: {n_affected}")

# Seleccionar aleatoriamente las pólizas afectadas
np.random.seed(1234)  # Nueva semilla para el shock
affected_policy_ids = np.random.choice(exposed_policies['IDpol'].values, 
                                       size=n_affected, 
                                       replace=False)

# Generar siniestros por granizada
shock_claims = []
claim_id_shock = 100000  # IDs separados para identificar siniestros de shock

for policy_id in affected_policy_ids:
    policy = df_policies[df_policies['IDpol'] == policy_id].iloc[0]
    
    # Severidad aumentada por el shock
    base_severity = policy['severity_mean']
    shock_severity = base_severity * SHOCK_SEVERITY_MULTIPLIER
    
    # Añadir variabilidad pero mantener el incremento
    claim_amount = np.random.gamma(shape=1/(1.2**2), scale=shock_severity * (1.2**2))
    claim_amount = np.clip(claim_amount, 1000, 500000)  # Mínimo más alto para granizo
    
    # Reporte muy rápido (1-3 días)
    delay_days = np.random.randint(SHOCK_REPORT_DELAY_DAYS[0], 
                                   SHOCK_REPORT_DELAY_DAYS[1] + 1)
    report_date = SHOCK_DATE + timedelta(days=delay_days)
    
    shock_claims.append({
        'claim_id': claim_id_shock,
        'policy_id': policy_id,
        'occurrence_date': SHOCK_DATE,
        'report_date': report_date,
        'delay_days': delay_days,
        'claim_amount': claim_amount,
        'area': policy['Area'],
        'driv_age': policy['DrivAge'],
        'veh_age': policy['VehAge'],
        'veh_power': policy['VehPower'],
        'is_catastrophic': True  # Marcar como catastrófico
    })
    claim_id_shock += 1

df_shock_claims = pd.DataFrame(shock_claims)

# Añadir marcador de catastrófico a claims originales
if 'is_catastrophic' not in df_claims.columns:
    df_claims['is_catastrophic'] = False

# Combinar con siniestros normales
df_claims_with_shock = pd.concat([df_claims, df_shock_claims], ignore_index=True)

# Estadísticas del shock
shock_total_amount = df_shock_claims['claim_amount'].sum()
shock_avg_amount = df_shock_claims['claim_amount'].mean()
normal_avg_in_d = df_claims[df_claims['area'] == SHOCK_AREA]['claim_amount'].mean()

print(f"\n{'='*80}")
print("ESTADÍSTICAS DEL SHOCK")
print(f"{'='*80}")
print(f"Número de siniestros generados: {len(df_shock_claims)}")
print(f"Monto total del evento: ${shock_total_amount:,.0f} MXN")
print(f"Severidad promedio (shock): ${shock_avg_amount:,.0f} MXN")
print(f"Severidad promedio normal (Zona D): ${normal_avg_in_d:,.0f} MXN")
print(f"Incremento: {(shock_avg_amount / normal_avg_in_d - 1) * 100:+.1f}%")
print(f"\nRetraso promedio de reporte: {df_shock_claims['delay_days'].mean():.1f} días")
print(f"  (vs {df_claims['delay_days'].mean():.1f} días en siniestros normales)")

# Visualización del impacto
fig, axes = plt.subplots(1, 3, figsize=(16, 5))
fig.suptitle('Impacto del Shock Catastrófico (Granizada)', fontsize=16, fontweight='bold')

# 1. Comparación de severidad
data_normal = df_claims[df_claims['area'] == SHOCK_AREA]['claim_amount'] / 1000
data_shock = df_shock_claims['claim_amount'] / 1000

axes[0].hist([data_normal, data_shock], bins=30, label=['Normal', 'Granizada'],
             color=['steelblue', 'crimson'], alpha=0.7, edgecolor='black')
axes[0].set_xlabel('Monto del Siniestro (Miles MXN)', fontsize=11)
axes[0].set_ylabel('Frecuencia', fontsize=11)
axes[0].set_title(f'Distribución de Severidad - Zona {SHOCK_AREA}', fontsize=12)
axes[0].legend()
axes[0].grid(alpha=0.3)

# 2. Serie temporal mostrando el spike
df_all_claims_temp = df_claims_with_shock.copy()
df_all_claims_temp['occurrence_month'] = pd.to_datetime(df_all_claims_temp['occurrence_date']).dt.to_period('M')
claims_by_month = df_all_claims_temp.groupby('occurrence_month').agg({
    'claim_id': 'count',
    'claim_amount': 'sum'
})

axes[1].plot(claims_by_month.index.to_timestamp(), claims_by_month['claim_id'],
             linewidth=2, marker='o', markersize=5, color='steelblue')
axes[1].axvline(SHOCK_DATE, color='red', linestyle='--', linewidth=2, label='Granizada')
axes[1].set_xlabel('Mes', fontsize=11)
axes[1].set_ylabel('Número de Siniestros', fontsize=11)
axes[1].set_title('Frecuencia Mensual de Siniestros', fontsize=12)
axes[1].legend()
axes[1].grid(alpha=0.3)
axes[1].tick_params(axis='x', rotation=45)

# 3. Monto total por mes
axes[2].bar(claims_by_month.index.to_timestamp(), claims_by_month['claim_amount'] / 1000000,
            color='mediumseagreen', alpha=0.7, edgecolor='black')
axes[2].axvline(SHOCK_DATE, color='red', linestyle='--', linewidth=2, label='Granizada')
axes[2].set_xlabel('Mes', fontsize=11)
axes[2].set_ylabel('Monto Total (Millones MXN)', fontsize=11)
axes[2].set_title('Monto Total Mensual de Siniestros', fontsize=12)
axes[2].legend()
axes[2].grid(axis='y', alpha=0.3)
axes[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

print(f"\n{'='*80}")
print("IMPACTO EN RESERVAS")
print(f"{'='*80}")
print("El shock catastrófico afecta las reservas de varias formas:")
print("1. ↑ Pagos en el año 2024 (año del evento)")
print("2. ↑ Factor de desarrollo para 2024 (reporte muy rápido)")
print("3. Posible distorsión en proyecciones si no se identifica como atípico")
print("\nEn la práctica, las aseguradoras:")
print("- Identifican y separan eventos catastróficos")
print("- Mantienen reservas específicas para catástrofes")
print("- Ajustan los triángulos excluyendo o normalizando estos eventos")

print(f"\n✓ Análisis de shock completado")
print(f"Total de siniestros (con shock): {len(df_claims_with_shock):,}")
print(f"  - Normales: {len(df_claims):,}")
print(f"  - Catastróficos: {len(df_shock_claims):,}")
# Out:
# ================================================================================
# SIMULANDO SHOCK CATASTRÓFICO: GRANIZADA EN ZONA D
# ================================================================================
#
# Evento: Granizada excepcional
# Fecha: 2024-06-15
# Zona afectada: D
# Tasa de impacto: 30%
# Multiplicador de severidad: 1.5x
#
# Generando siniestros catastróficos...
#
# Pólizas en Zona D activas en la fecha: 199
# Pólizas afectadas por la granizada: 59
#
# ================================================================================
# ESTADÍSTICAS DEL SHOCK
# ================================================================================
# Número de siniestros generados: 59
# Monto total del evento: $4,069,269 MXN
# Severidad promedio (shock): $68,971 MXN
# Severidad promedio normal (Zona D): $29,554 MXN
# Incremento: +133.4%
#
# Retraso promedio de reporte: 2.0 días
#   (vs 17.8 días en siniestros normales)
# ================================================================================
# IMPACTO EN RESERVAS
# ================================================================================
# El shock catastrófico afecta las reservas de varias formas:
# 1. ↑ Pagos en el año 2024 (año del evento)
# 2. ↑ Factor de desarrollo para 2024 (reporte muy rápido)
# 3. Posible distorsión en proyecciones si no se identifica como atípico
#
# En la práctica, las aseguradoras:
# - Identifican y separan eventos catastróficos
# - Mantienen reservas específicas para catástrofes
# - Ajustan los triángulos excluyendo o normalizando estos eventos
#
# ✓ Análisis de shock completado
# Total de siniestros (con shock): 528
#   - Normales: 469
#   - Catastróficos: 59

# %%
# Cálculos de loss ratio ajustado
total_incurred_det = total_paid + total_ibnr_det
total_incurred_cl_boot = total_paid + mean_ibnr
total_incurred_bf_boot = total_paid + ibnr_bf_boot.mean()

loss_ratio_adj_det = total_incurred_det / total_premium
loss_ratio_adj_cl_boot = total_incurred_cl_boot / total_premium
loss_ratio_adj_bf_boot = total_incurred_bf_boot / total_premium

print('Loss ratio ajustado (determinista):', loss_ratio_adj_det)
print('Loss ratio ajustado (CL bootstrap):', loss_ratio_adj_cl_boot)
print('Loss ratio ajustado (BF bootstrap):', loss_ratio_adj_bf_boot)

comparison = pd.DataFrame({
    'Método': ['Chain Ladder determinista', 'Chain Ladder bootstrap',
               'Bornhuetter–Ferguson determinista', 'Bornhuetter–Ferguson bootstrap'],
    'IBNR estimado': [total_ibnr_det, mean_ibnr, total_ibnr_bf_det, ibnr_bf_boot.mean()],
    'Desviación estándar': [0.0, std_ibnr, 0.0, ibnr_bf_boot.std()]
})
comparison
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Cálculos de loss ratio ajustado
# ----> 2 total_incurred_det = total_paid + total_ibnr_det
#       3 total_incurred_cl_boot = total_paid + mean_ibnr
#       4 total_incurred_bf_boot = total_paid + ibnr_bf_boot.mean()
#
# NameError: name 'total_paid' is not defined
